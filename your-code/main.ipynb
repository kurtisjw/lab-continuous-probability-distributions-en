# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# !pip install scipy
from scipy.stats import uniform
# Define the range
lower_bound = 10
upper_bound = 20

# Define the number of random numbers you want to generate
num_samples = 5

# Generate uniform random numbers
random_numbers = uniform.rvs(loc=lower_bound, scale=upper_bound-lower_bound, size=num_samples)

print("Generated random numbers:", random_numbers)
# Out:
# ...
# Generated random numbers: [10.9540585  18.1222066  15.54162854 15.73739654 17.16953914]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def generate_uniform_random_numbers(bottom, ceiling, count):
    """
    Generates an array of uniformly distributed random numbers.

    Parameters:
    bottom (float): The lower boundary of the generated numbers.
    ceiling (float): The upper boundary of the generated numbers.
    count (int): The number of random numbers to generate.

    Returns:
    numpy.ndarray: An array of uniformly distributed random numbers.
    """
    # Generate uniform random numbers
    random_numbers = uniform.rvs(loc=bottom, scale=ceiling-bottom, size=count)
    
    return random_numbers

# %%
# Call the function with the specified parameters
random_numbers_1 = generate_uniform_random_numbers(10, 15, 100)
random_numbers_2 = generate_uniform_random_numbers(10, 60, 1000)

# %%
# Plotting the histograms
def plot_histogram(data, bins, title):
    plt.hist(data, bins=bins, edgecolor='black')
    plt.title(title)
    plt.xlabel('Value')
    plt.ylabel('Count')
    plt.grid(False)
    plt.show()

# Plot the histogram for the first set of random numbers
plot_histogram(random_numbers_1, bins=10, title='Uniform Distribution (10, 15) with 100 samples')

# Plot the histogram for the second set of random numbers
plot_histogram(random_numbers_2, bins=10, title='Uniform Distribution (10, 60) with 1000 samples')

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
def generate_normal_random_numbers(mean, stddev, count):
    """
    Generates an array of normally distributed random numbers.

    Parameters:
    mean (float): The mean (average) of the distribution.
    stddev (float): The standard deviation of the distribution.
    count (int): The number of random numbers to generate.

    Returns:
    numpy.ndarray: An array of normally distributed random numbers.
    """
    random_numbers = norm.rvs(loc=mean, scale=stddev, size=count)
    return random_numbers

def plot_histogram(data, bins, title):
    plt.hist(data, bins=bins, edgecolor='black')
    plt.title(title)
    plt.xlabel('Value')
    plt.ylabel('Count')
    plt.grid(True)
    plt.show()

# Generate the random numbers
normal_random_numbers_1 = generate_normal_random_numbers(10, 1, 1000)
normal_random_numbers_2 = generate_normal_random_numbers(10, 50, 1000)

# Plot the histograms
plot_histogram(normal_random_numbers_1, bins=50, title='Normal Distribution (mean=10, stddev=1) with 1000 samples')
plot_histogram(normal_random_numbers_2, bins=50, title='Normal Distribution (mean=10, stddev=50) with 1000 samples')

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# The standard deviation of the second histogram is much larger which means there is a greater dispersion of values in relation to the mean.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# ## First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicles = pd.read_csv('vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
# Plot the histogram for the 'Fuel Barrels/Year' variable
plt.hist(vehicles['Fuel Barrels/Year'], bins=10, edgecolor='black')
plt.title('Distribution of Fuel Barrels/Year')
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# Plot the histogram for the 'CO2 Emission Grams/Mile' variable
plt.subplot(1, 2, 2)  # Create a subplot (1 row, 2 columns, 2nd plot)
plt.hist(vehicles['CO2 Emission Grams/Mile'], bins=10, edgecolor='black')
plt.title('Distribution of CO2 Emission Grams/Mile')
plt.xlabel('CO2 Emission Grams/Mile')
plt.ylabel('Count')
plt.grid(True)

# Display the plots
plt.tight_layout()  # Adjust subplots to fit into the figure area.
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
# Plot the histogram for the 'Combined MPG' variable
plt.subplot(1, 3, 3)  # Create a subplot (1 row, 3 columns, 3rd plot)
plt.hist(vehicles['Combined MPG'], bins=10, edgecolor='black')
plt.title('Distribution of Combined MPG')
plt.xlabel('Combined MPG')
plt.ylabel('Count')
plt.grid(True)

# Adjust subplots to fit into the figure area.
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# None of them are normally distributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# Create function that returns a list of exponentially distributed numbers

def generate_exponentially_distributed_numbers(mean,size,):
    return np.random.exponential(scale = mean, size = size)

sequence_1 = generate_exponentially_distributed_numbers(10, 10)
sequence_2 = generate_exponentially_distributed_numbers(10, 100)


def plot_histogram(data, bins, title):
    plt.hist(data, bins=bins, edgecolor='black')
    plt.title(title)
    plt.xlabel('Value')
    plt.ylabel('Count')
    plt.grid(False)
    plt.show()

# Plot the histograms
plot_histogram(sequence_1, bins=50, title='Normal Distribution (mean=10, stddev=1) with 1000 samples')
plot_histogram(sequence_2, bins=50, title='Normal Distribution (mean=10, stddev=50) with 1000 samples')

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your code here
